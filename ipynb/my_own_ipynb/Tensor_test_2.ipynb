# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib as plt
import timeit
from datetime import datetime
(x_train, y_train), (x_test,y_test) = keras.datasets.cifar10.load_data()

#checking images shape
x_train.shape, x_test.shape

#checking labels
y_train[:5]

#scaling image values between 0-1
x_train_scaled = x_train/255
x_test_scaled = x_test/255

#one hot encolding labels
y_train_encoded = keras.utils.to_categorical(y_train, num_classes = 10, dtype= 'float32')
y_test_encoded = keras.utils.to_categorical(y_test, num_classes = 10, dtype = 'float32')

#Building model

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(3000, activation='relu'),
    keras.layers.Dense(1000, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
# Model summary and Evaluation
model.summary()
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
start = datetime.now()
model.fit(x_train_scaled, y_train_encoded, batch_size=128, epochs=10, validation_split=0.1)
stop = datetime.now()
print("Time taken to execute:" + str(stop - start))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 3000)              9219000
#
#  dense_1 (Dense)             (None, 1000)              3001000
#
#  dense_2 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 12,230,010
# Trainable params: 12,230,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 352/352 [==============================] - 3s 7ms/step - loss: 0.5497 - accuracy: 0.8038 - val_loss: 0.9947 - val_accuracy: 0.6728
# Epoch 2/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.5259 - accuracy: 0.8136 - val_loss: 1.0280 - val_accuracy: 0.6708
# Epoch 3/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.5137 - accuracy: 0.8161 - val_loss: 1.0025 - val_accuracy: 0.6710
# Epoch 4/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.5030 - accuracy: 0.8185 - val_loss: 1.0379 - val_accuracy: 0.6740
# Epoch 5/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.4982 - accuracy: 0.8221 - val_loss: 1.0899 - val_accuracy: 0.6594
# Epoch 6/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.4914 - accuracy: 0.8230 - val_loss: 1.1383 - val_accuracy: 0.6568
# Epoch 7/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.4804 - accuracy: 0.8283 - val_loss: 1.1579 - val_accuracy: 0.6586
# Epoch 8/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.4692 - accuracy: 0.8343 - val_loss: 1.2592 - val_accuracy: 0.6456
# Epoch 9/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.4613 - accuracy: 0.8343 - val_loss: 1.2541 - val_accuracy: 0.6500
# Epoch 10/10
# 352/352 [==============================] - 2s 6ms/step - loss: 0.4668 - accuracy: 0.8330 - val_loss: 1.2535 - val_accuracy: 0.6518
# Time taken to execute:0:00:23.531652

# %%
#GPU
start_time = datetime.now()
with tf.device('/GPU:0'):
    model_gpu = model
    model_gpu.fit(x_train_scaled, y_train_encoded, epochs=10)

end_time = datetime.now()

print(f"This test is trained with RTX 3060 for : {end_time-start_time}")
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0967 - accuracy: 0.6380
# Epoch 2/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8140 - accuracy: 0.7135
# Epoch 3/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7795 - accuracy: 0.7259
# Epoch 4/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7629 - accuracy: 0.7291
# Epoch 5/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7471 - accuracy: 0.7327
# Epoch 6/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7443 - accuracy: 0.7363
# Epoch 7/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7448 - accuracy: 0.7346
# Epoch 8/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7390 - accuracy: 0.7373
# Epoch 9/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7178 - accuracy: 0.7452
# Epoch 10/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7148 - accuracy: 0.7466
# This test is trained with RTX 3060 for : 0:01:22.880043
